# %%
import iop_svds as io
import numpy as np
filename = '/Users/Agah/Desktop/NIST_Process/Data3/Outputs'
aa = io.load_svds(filename)
print(np.shape(aa))
print(len(aa[0]))
print(len(aa[1]))
print(len(aa[2]))
# Out:
# Pearson.json is SVDS
# Spearman.json is SVDS
# Concordance.json is SVDS
# (3, 30)
# 30
# 30
# 30

# %%
# Out:
# [{'Tag': {'SegmentID': [1], 'Class': 'Bivariate::Pearson'}, 'Required': {'xData': [1979.2, 1950.15, 1966.8, 1929.1, 1939.65, 1955.65, 1961.55, 1974.6, 1914.9, 1935, 1931.85, 1931.75, 1926.95, 1919.7, 1936.95, 1950.1, 1947.3, 1950.9, 1932.15, 1920.6, 1934.65, 1917.4, 1944.85, 1889.9, 1961.45, 1926.35, 1934.5, 1930.45, 1924.75, 1933.9, 1913.65, 1959.65, 1906.9, 1954.6, 1894.1, 1921.3, 1948.45, 1949.85, 1932.3, 1944.8, 1924.35, 1981.2, 1915.25, 1949.55, 1892, 1924.85, 1932.2, 1931.9, 1915.7, 1937.85, 1910.6, 1961.55, 1905.1, 1962.35, 1898.15, 1928.7, 1956, 1939.55, 1926.3, 1946.9, 1917.55, 1952.2, 1886.45, 1969.85, 1913.3, 1930.25, 1922.9, 1923.7, 1915.55, 1918.15, 1969.55, 1953.3, 1983.15, 1941.55, 1953.5, 1958.9, 1978.75], 'yData': [1986.4, 1936.9, 1961.4, 1924.5, 1936.1, 1951.6, 1958.4, 1956.3, 1917.1, 1928.3, 1935.3, 1914.7, 1928.5, 1893.6, 1959, 1913.9, 1929.2, 1950.8, 1925, 1909.6, 1929.3, 1906.1, 1950.3, 1866.5, 1972.2, 1918.3, 1912.1, 1924.7, 1915.4, 1931.4, 1897.7, 1966.7, 1889
# ...
